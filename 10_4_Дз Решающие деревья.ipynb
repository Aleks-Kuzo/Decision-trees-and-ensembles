# %% [markdown]
# # Решающие деревья. Практика

# %% [markdown]
# В этом задании будем решать задачу классификации клиентов телекома: для каждого клиента необходимо определить, перестанет он пользоваться услугами оператора (оттоковый клиент) в ближайшее время или нет.
#
# В ноутбуке будем использовать несколько моделей, в том числе SVM, поэтому установим библиотеку для быстрого обучения SVM.

# %% [markdown]
# ## Импорт библиотек и загрузка данных

# %%
from sklearnex import patch_sklearn
patch_sklearn()
# Out:
# Extension for Scikit-learn* enabled (https://github.com/uxlfoundation/scikit-learn-intelex)

# %%
import sys
import os
import site
import pandas as pd
import numpy as np

sys.path.append(os.path.join(os.path.dirname(site.getsitepackages()[0]), "site-packages"))

# %%
# зафиксируем константы
RANDOM_STATE = 42

# %%
df = pd.read_csv("https://raw.githubusercontent.com/evgpat/edu_stepik_practical_ml/main/datasets/telecom_churn.csv")
df.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# 1             27.47              195.5              103             16.62
# 2             41.38              121.2              110             10.30
# 3             50.90               61.9               88              5.26
# 4             28.34              148.3              122             12.61
#
#    Total night minutes  Total night calls  Total night charge  \
# 0                244.7                 91               11.01
# 1                254.4                103               11.45
# 2                162.6                104                7.32
# 3                196.9                 89                8.86
# 4                186.9                121                8.41
#
#    Total intl minutes  Total intl calls  Total intl charge  \
# 0                10.0                 3               2.70
# 1                13.7                 3               3.70
# 2                12.2                 5               3.29
# 3                 6.6                 7               1.78
# 4                10.1                 3               2.73
#
#    Customer service calls  Churn
# 0                       1  False
# 1                       1  False
# 2                       0  False
# 3                       2  False
# 4                       3  False

# %% [markdown]
# ## Практика

# %%
np.random.seed(RANDOM_STATE)

# %% [markdown]
# Сделайте первичную обработку данных:
#
# 1) Выбросите колонку State
#
# 2) Колонки International plan и Voice mail plan закодируйте следующим образом: "Yes" замените на 1, а "No" на 0.
#
# 3) Переведите целевую переменную (Churn) в числа: True в 1, а False в 0.

# %%
# your code here
df = df.drop('State', axis=1)
df['International plan'] = df['International plan'].map({'Yes': 1, 'No': 0})
df['Voice mail plan'] = df['Voice mail plan'].map({'Yes': 1, 'No': 0})
df['Churn'] = df['Churn'].astype(int)

# %% [markdown]
# ### Вопрос
#
# Чему равна сумма значений в закодированном столбце International plan?

# %%
# your code here
print(df['International plan'].sum())
# Out:
# 323

# %% [markdown]
# Выведите на экран первые строки измененной таблицы, чтобы проверить, что все преобразования сработали.

# %%
# your code here
df[:5]
# Out:
#    Account length  Area code  International plan  Voice mail plan  \
# 0             128        415                   0                1
# 1             107        415                   0                1
# 2             137        415                   0                0
# 3              84        408                   1                0
# 4              75        415                   1                0
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# 1             27.47              195.5              103             16.62
# 2             41.38              121.2              110             10.30
# 3             50.90               61.9               88              5.26
# 4             28.34              148.3              122             12.61
#
#    Total night minutes  Total night calls  Total night charge  \
# 0                244.7                 91               11.01
# 1                254.4                103               11.45
# 2                162.6                104                7.32
# 3                196.9                 89                8.86
# 4                186.9                121                8.41
#
#    Total intl minutes  Total intl calls  Total intl charge  \
# 0                10.0                 3               2.70
# 1                13.7                 3               3.70
# 2                12.2                 5               3.29
# 3                 6.6                 7               1.78
# 4                10.1                 3               2.73
#
#    Customer service calls  Churn
# 0                       1      0
# 1                       1      0
# 2                       0      0
# 3                       2      0
# 4                       3      0

# %% [markdown]
# Создайте матрицу объект-признак X и вектор с целевой переменной (Churn) y.

# %%
# your code here
x = df.drop('Churn', axis=1)
y = df['Churn']

# %% [markdown]
# ### Вопрос
#
# Проверьте баланс классов. Является ли выборка сбалансированной?

# %%
# your code here
y.value_counts()
# Out:
# Churn
# 0    2850
# 1     483
# Name: count, dtype: int64

# %% [markdown]
# По кросс-валидации с тремя фолдами и метрикой ROC-AUC (scoring='roc_auc') обучите:
#
# 1) Логистическую регрессию
#
# 2) Метод опорных векторов (с kernel='linear')
#
# Выведите на экран среднее качество моделей на кросс-валидации.
#
# При объявлении SVC не забудьте указать в гиперпараметрах probability = True (так как метод изначально не предсказывает вероятности классов, а они нам нужны для вычисления ROC-AUC).

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.model_selection import cross_val_score

lr = LogisticRegression(random_state=RANDOM_STATE, max_iter=1000)
lr_cv = cross_val_score(lr, x, y, cv=3, scoring='roc_auc').mean()

print(f"LR  CV ROC-AUC: {lr_cv:.4f}")
# Out:
# LR  CV ROC-AUC: 0.8136

# %%
svm = SVC(kernel='linear', random_state=RANDOM_STATE)
svm_cv = cross_val_score(svm, x, y, cv=3, scoring='roc_auc').mean()

print(f"SVM CV ROC-AUC: {svm_cv:.4f}")

# %% [markdown]
# Теперь обучите решающее дерево с параметрами по умолчанию по кросс-валидации с тремя фолдами и той же метрикой.
#
# ВАЖНО! У решающего дерева для воспроизводимости результатов фиксируйте random_state = RANDOM_STATE

# %%
from sklearn.tree import DecisionTreeClassifier

# your code here
tree = DecisionTreeClassifier(random_state=RANDOM_STATE)
tree_cv = cross_val_score(tree, x, y, cv=3, scoring='roc_auc').mean()
print(f"DT  CV ROC-AUC: {tree_cv:.4f}")
# Out:
# DT  CV ROC-AUC: 0.8361

# %% [markdown]
# ### Вопрос
#
# Какой из трех алгоритмов показал наилучшее качество на кросс-валидации?

# %% [markdown]
# Ваша цель - максимально улучшить модели. Для этого:
#
# 1) у линейных моделей подберите гиперпараметр С (переберите 20 значений C в диапазоне от 0.1 до 10 с равным шагом).
#
# 2) у решающего дерева подберите max_depth (переберите глубину от 1 до 10 с шагом 1) и criterion - "gini" или "entropy".
#
# Для подбора параметров используйте GridSearchCV с тремя фолдами и метрикой roc-auc или обычные циклы.
#
# Подбор параметров осуществляется только по тренировочным данным!

# %% [markdown]
# При подборе гиперпараметров по кросс-валидации для дальнейшей корректной оценки качества модели нужна отдельная выборка. Давайте сразу действовать правильно:
#
# 1) сначала разбиваем (как и раньше) данные на тренировочную и тестовую части
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 2) затем по тренировочной части при помощи GridSearchCV подбираем оптимальные значения гиперпараметров
#
# 3) наконец, делаем предсказание модели с оптимальными гиперпараметрами на тестовых данных и уже по ним оцениваем итоговую метрику.
#
# Сложно, зато правильно!

# %% [markdown]
# Первую модель обучим для примера. Дальше вы сами.

# %%
from sklearn.model_selection import train_test_split

xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.3, random_state=RANDOM_STATE)

# %%
from sklearn.model_selection import GridSearchCV

params = {'C' : np.linspace(0.1, 10.01, 20)}

gs = GridSearchCV(LogisticRegression(random_state=RANDOM_STATE, max_iter=1000), params, cv=3, scoring='roc_auc')

gs.fit(xtrain, ytrain)

gs.best_score_, gs.best_estimator_
# Out:
# (np.float64(0.8001462968114389),
#  LogisticRegression(C=np.float64(9.488421052631578), max_iter=1000,
#                     random_state=42))

# %%
from sklearn.metrics import roc_auc_score

lr = gs.best_estimator_

pred_lr = lr.predict_proba(xtest)[:,1]
print(f'Logisctic Regression Score{roc_auc_score(ytest, pred_lr)}')
# Out:
# Logisctic Regression Score0.8283082145392531

# %%
# your code here
params_tree = {'max_depth': np.arange(1,11), 'criterion':['gini','entropy']}
tree_gs = GridSearchCV(DecisionTreeClassifier(random_state=RANDOM_STATE), params_tree, cv=3, scoring='roc_auc')
tree_gs.fit(xtrain, ytrain)
tree_gs.best_estimator_, tree_gs.best_score_
# Out:
# (DecisionTreeClassifier(max_depth=np.int64(6), random_state=42),
#  np.float64(0.8644263148363854))

# %%
tree_pred = tree_gs.best_estimator_.predict_proba(xtest)[:,1]
print(f'Decision Tree Score: {roc_auc_score(ytest, tree_pred)}')
# Out:
# Decision Tree Score: 0.8555540142471297

# %%
svm_params = {'C':np.linspace(0.1,10.01,20)}
svm_gs = GridSearchCV(SVC(kernel='linear', probability=True, random_state=RANDOM_STATE), svm_params, cv=3, scoring='roc_auc')
svm_gs.fit(xtrain, ytrain)
svm_gs.best_estimator_, svm_gs.best_score_
# Out:
# c:\Users\arato\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearnex\svm\_base.py:362: RuntimeWarning: random_state does not influence oneDAL SVM results
#   warnings.warn(
# c:\Users\arato\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearnex\svm\_base.py:362: RuntimeWarning: random_state does not influence oneDAL SVM results
#   warnings.warn(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[52], line 3
#       1 svm_params = {'C':np.linspace(0.1,10.01,20)}
#       2 svm_gs = GridSearchCV(SVC(kernel='linear', probability=True, random_state=RANDOM_STATE), svm_params, cv=3, scoring='roc_auc')
# ----> 3 svm_gs.fit(xtrain, ytrain)
#       4 svm_gs.best_estimator_, svm_gs.best_score_
#
# File c:\Users\arato\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py:1336, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1329     estimator._validate_params()
#    1331 with config_context(
#    1332     skip_parameter_validation=(
#    1333         prefer_skip_nested_validation or global_skip_validation
#    1334     )
#    1335 ):
# -> 1336     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\arato\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\model_selection\_search.py:1053, in BaseSearchCV.fit(self, X, y, **params)
#    1047     results = self._format_results(
#    1048         all_candidate_params, n_splits, all_out, all_more_results
#    1049     )
#    1051     return results
# -> 1053 self._run_search(evaluate_candidates)
#    1055 # multimetric is determined here because in the case of a callable
#    1056 # self.scoring the return type is only known after calling
#    1057 first_test_score = all_out[0]["test_scores"]
#
# File c:\Users\arato\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\model_selection\_search.py:1612, in GridSearchCV._run_search(self, evaluate_candidates)
#    1610 def _run_search(self, evaluate_candidates):
#    1611     """Search all candidates in param_grid"""
# -> 1612     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File c:\Users\arato\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\model_selection\_search.py:999, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     991 if self.verbose > 0:
#     992     print(
#     993         "Fitting {0} folds for each of {1} candidates,"
#     994         " totalling {2} fits".format(
#     995             n_splits, n_candidates, n_candidates * n_splits
#     996         )
#     997     )
# --> 999 out = parallel(
#    1000     delayed(_fit_and_score)(
#    1001         clone(base_estimator),
#    1002         X,
#    1003         y,
#    1004         train=train,
#    1005         test=test,
#    1006         parameters=parameters,
#    1007         split_progress=(split_idx, n_splits),
#    1008         candidate_progress=(cand_idx, n_candidates),
#    1009         **fit_and_score_kwargs,
#    1010     )
#    1011     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#    1012         enumerate(candidate_params),
#    1013         enumerate(cv.split(X, y, **routed_params.splitter.split)),
#    1014     )
#    1015 )
#    1017 if len(out) < 1:
#    1018     raise ValueError(
#    1019         "No fits were performed. "
#    1020         "Was the CV iterator empty? "
#    1021         "Were there no candidates?"
#    1022     )
#
# File c:\Users\arato\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\parallel.py:91, in Parallel.__call__(self, iterable)
#      79 warning_filters = (
#      80     filters_func() if filters_func is not None else warnings.filters
#      81 )
#      83 iterable_with_config_and_warning_filters = (
#      84     (
#      85         _with_config_and_warning_filters(delayed_func, config, warning_filters),
#    (...)     89     for delayed_func, args, kwargs in iterable
#      90 )
# ---> 91 return super().__call__(iterable_with_config_and_warning_filters)
#
# File c:\Users\arato\AppData\Local\Programs\Python\Python313\Lib\site-packages\joblib\parallel.py:1986, in Parallel.__call__(self, iterable)
#    1984     output = self._get_sequential_output(iterable)
#    1985     next(output)
# -> 1986     return output if self.return_generator else list(output)
#    1988 # Let's create an ID that uniquely identifies the current call. If the
#    1989 # call is interrupted early and that the same instance is immediately
#    1990 # reused, this id will be used to prevent workers that were
#    1991 # concurrently finalizing a task from the previous call to run the
#    1992 # callback.
#    1993 with self._lock:
#
# File c:\Users\arato\AppData\Local\Programs\Python\Python313\Lib\site-packages\joblib\parallel.py:1914, in Parallel._get_sequential_output(self, iterable)
#    1912 self.n_dispatched_batches += 1
#    1913 self.n_dispatched_tasks += 1
# -> 1914 res = func(*args, **kwargs)
#    1915 self.n_completed_tasks += 1
#    1916 self.print_progress()
#
# File c:\Users\arato\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearnex\utils\parallel.py:56, in _FuncWrapper.__call__(self, *args, **kwargs)
#      54 with config_context(**config), warnings.catch_warnings():
#      55     warnings.filters = warning_filters
# ---> 56     return self.function(*args, **kwargs)
#
# File c:\Users\arato\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\model_selection\_validation.py:833, in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, score_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     831         estimator.fit(X_train, **fit_params)
#     832     else:
# --> 833         estimator.fit(X_train, y_train, **fit_params)
#     835 except Exception:
#     836     # Note fit time as time until error
#     837     fit_time = time.time() - start_time
#
# File c:\Users\arato\AppData\Local\Programs\Python\Python313\Lib\site-packages\daal4py\sklearn\_n_jobs_support.py:113, in _run_with_n_jobs.<locals>.n_jobs_wrapper(self, *args, **kwargs)
#     110 if n_jobs is None or n_jobs == 0:
#     111     if n_threads is None:
#     112         # default branch with no setting for n_jobs
# --> 113         return method(self, *args, **kwargs)
#     114     else:
#     115         n_jobs = n_threads
#
# File c:\Users\arato\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearnex\svm\_classes.py:105, in SVC.fit(self, X, y, sample_weight)
#      94 elif self.C <= 0:
#      95     # else if added to correct issues with
#      96     # sklearn tests:
#    (...)    102     # Windows fatal exception: access violation
#     103     # occurs
#     104     raise ValueError("'C' must be strictly positive.")
# --> 105 dispatch(
#     106     self,
#     107     "fit",
#     108     {
#     109         "onedal": self.__class__._onedal_fit,
#     110         "sklearn": _sklearn_SVC.fit,
#     111     },
#     112     X,
#     113     y,
#     114     sample_weight,
#     115 )
#     117 return self
#
# File c:\Users\arato\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearnex\_device_offload.py:152, in dispatch(obj, method_name, branches, *args, **kwargs)
#     150     queue = QM.get_global_queue()
#     151     patching_status.write_log(queue=queue, transferred_to_host=False)
# --> 152     return branches["onedal"](obj, *hostargs, **hostkwargs, queue=queue)
#     153 else:
#     154     if sklearn_array_api and not has_usm_data:
#     155         # dpnp fallback is not handled properly yet.
#
# File c:\Users\arato\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearnex\svm\_base.py:346, in BaseSVC._onedal_fit(self, X, y, sample_weight, queue)
#     341 self._onedal_estimator.fit(
#     342     X, y, sample_weight, class_count=self.classes_.shape[0], queue=queue
#     343 )
#     345 if self.probability:
# --> 346     self._fit_proba(
#     347         X,
#     348         y,
#     349         sample_weight=sample_weight,
#     350         queue=queue,
#     351     )
#     353 self._save_attributes(X, y, xp=xp)
#
# File c:\Users\arato\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearnex\svm\_base.py:377, in BaseSVC._fit_proba(self, X, y, sample_weight, queue)
#     375 cfg["target_offload"] = queue
#     376 with config_context(**cfg):
# --> 377     clf_base.fit(X, y)
#     379     # Forced use of FrozenEstimator starting in sklearn 1.6
#     380     if sklearn_check_version("1.6"):
#
# File c:\Users\arato\AppData\Local\Programs\Python\Python313\Lib\site-packages\daal4py\sklearn\_n_jobs_support.py:113, in _run_with_n_jobs.<locals>.n_jobs_wrapper(self, *args, **kwargs)
#     110 if n_jobs is None or n_jobs == 0:
#     111     if n_threads is None:
#     112         # default branch with no setting for n_jobs
# --> 113         return method(self, *args, **kwargs)
#     114     else:
#     115         n_jobs = n_threads
#
# File c:\Users\arato\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearnex\svm\_classes.py:105, in SVC.fit(self, X, y, sample_weight)
#      94 elif self.C <= 0:
#      95     # else if added to correct issues with
#      96     # sklearn tests:
#    (...)    102     # Windows fatal exception: access violation
#     103     # occurs
#     104     raise ValueError("'C' must be strictly positive.")
# --> 105 dispatch(
#     106     self,
#     107     "fit",
#     108     {
#     109         "onedal": self.__class__._onedal_fit,
#     110         "sklearn": _sklearn_SVC.fit,
#     111     },
#     112     X,
#     113     y,
#     114     sample_weight,
#     115 )
#     117 return self
#
# File c:\Users\arato\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearnex\_device_offload.py:152, in dispatch(obj, method_name, branches, *args, **kwargs)
#     150     queue = QM.get_global_queue()
#     151     patching_status.write_log(queue=queue, transferred_to_host=False)
# --> 152     return branches["onedal"](obj, *hostargs, **hostkwargs, queue=queue)
#     153 else:
#     154     if sklearn_array_api and not has_usm_data:
#     155         # dpnp fallback is not handled properly yet.
#
# File c:\Users\arato\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearnex\svm\_base.py:341, in BaseSVC._onedal_fit(self, X, y, sample_weight, queue)
#     327 onedal_params = {
#     328     "C": self.C,
#     329     "nu": self.nu,
#    (...)    337     "cache_size": self.cache_size,
#     338 }
#     340 self._onedal_estimator = self._onedal_factory(**onedal_params)
# --> 341 self._onedal_estimator.fit(
#     342     X, y, sample_weight, class_count=self.classes_.shape[0], queue=queue
#     343 )
#     345 if self.probability:
#     346     self._fit_proba(
#     347         X,
#     348         y,
#     349         sample_weight=sample_weight,
#     350         queue=queue,
#     351     )
#
# File c:\Users\arato\AppData\Local\Programs\Python\Python313\Lib\site-packages\onedal\_device_offload.py:59, in supports_queue.<locals>.wrapper(self, *args, **kwargs)
#      57 with QM.manage_global_queue(queue, *args) as queue:
#      58     kwargs["queue"] = queue
# ---> 59     result = func(self, *args, **kwargs)
#      60 return result
#
# File c:\Users\arato\AppData\Local\Programs\Python\Python313\Lib\site-packages\onedal\svm\svm.py:110, in BaseSVM.fit(self, X, y, sample_weight, class_count, queue)
#     108 data_t = to_table(*data, queue=queue)
#     109 params = self._get_onedal_params(data_t[0])
# --> 110 result = self.train(params, *data_t)
#     112 if self._sparse:
#     113     self.dual_coef_ = sp.csr_matrix(from_table(result.coeffs).T)
#
# KeyboardInterrupt:

# %%
svm_pred = svm_gs.best_estimator_.predict_proba(xtest)[:,1]
print(f'SVM Score: {roc_auc_score(ytest, svm_pred)}')
# Out:
# SVM Score: 0.7400102814338521
# c:\Users\arato\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2684: UserWarning: X has feature names, but SVC was fitted without feature names
#   warnings.warn(

# %% [markdown]
# ### Вопрос
#
# Чему равно качество решающего дерева с подобранными гиперпараметрами, посчитанное на тестовой выборке?
#
# Ответ округлите до сотых.

# %% [markdown]
# Какая модель справилась с решением задачи лучше всего по метрике roc_auc?

# %% [markdown]
# Нарисуйте roc-кривую для наилучшей модели.

# %%
from sklearn.metrics import roc_curve
from matplotlib import pyplot as plt

# your code here
pred_best = tree_pred  # или pred_svm / pred_dt
best_auc = roc_auc_score(ytest, pred_best)

fpr, tpr, _ = roc_curve(ytest, pred_best)
plt.figure(figsize=(6,5))
plt.plot(fpr, tpr, label=f'ROC curve (AUC = {best_auc:.3f})', linewidth=2)
plt.plot([0, 1], [0, 1], 'k--', label='Random Guess')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for the Best Model')
plt.legend(loc='lower right')
plt.grid(alpha=0.3)
plt.show()

# %% [markdown]
# Сравните между собой две лучшие модели.

# %% [markdown]
# ### Вопрос
#
# Насколько сильно отличается качество предсказания на тестовых данных?
# (вычислите разность значений roc-auc)

# %%
# your code here
diff = abs(roc_auc_score(ytest, tree_pred) - roc_auc_score(ytest, pred_lr))  # замените на ваши переменные
print(f"Разность ROC-AUC: {diff:.4f}")
# Out:
# Разность ROC-AUC: 0.0272

# %% [markdown]
# Постройте гистограммы важности признаков (для линейных моделей берите модуль значений весов) для каждой из этих моделей. Сравните между собой списки из трех самых важных признаков. Совпадают ли они?

# %% [markdown]
# ### Вопрос
#
# Какой признак наиболее важен для решающего дерева?

# %%
# your code here
importances_dt = tree_gs.best_estimator_.feature_importances_
print(x.columns[importances_dt.argmax()])
# Out:
# Total day charge

# %% [markdown]
# Сделайте выводы (для себя)
#
# 1) Являются ли данные сбалансированными? Что это означает?
#
# 2) Какая модель после подбора гиперпараметров лучше всего решает задачу с точки зрения метрики roc-auc?
#
# 3) Одинаковые ли признаки важны для работы двух наилучших моделей? Как вы думаете, почему так?
